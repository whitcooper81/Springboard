# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'yPExQevyx6K6rQvq7Jfu'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import collections
import json

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = "https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?collapse=daily&rows=6&order=asc&column_index=1&start_date=2020-01-06&end_date=2020-01-06&api_key={}".format(API_KEY)

# %%
r = requests.get(url)
json_data = r.json()

# %%
r
# Out:
# <Response [200]>

# %%
json_data
# Out:
# {'dataset': {'id': 10095370,
#   'dataset_code': 'AFX_X',
#   'database_code': 'FSE',
#   'name': 'Carl Zeiss Meditec (AFX_X)',
#   'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704',
#   'refreshed_at': '2020-12-01T14:48:09.907Z',
#   'newest_available_date': '2020-12-01',
#   'oldest_available_date': '2000-06-07',
#   'column_names': ['Date', 'Open'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': 6,
#   'transform': None,
#   'column_index': 1,
#   'start_date': '2020-01-06',
#   'end_date': '2020-01-06',
#   'data': [['2020-01-06', 112.0]],
#   'collapse': 'daily',
#   'order': 'asc',
#   'database_id': 6129}}

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
url = 'https://www.quandl.com/api/v3/datasets/XFRA/AGB2_UADJ?start_date=2017-1-1&end_date=2017-12-31&api_key=yPExQevyx6K6rQvq7Jfu'
r=requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
json_data = r.json()

# %%
json_data['dataset']['data']
# Out:
# [['2017-12-29', 103.333, 103.999, 103.288, 103.288, 310.0, None, None],
#  ['2017-12-28', 102.389, 102.389, 102.389, 102.389, 0.0, None, None],
#  ['2017-12-27', 102.574, 103.6, 102.574, 103.6, 404.0, None, None],
#  ['2017-12-26', 102.958, 102.958, 102.958, 102.958, 0.0, None, None],
#  ['2017-12-25', 102.958, 102.958, 102.958, 102.958, 0.0, None, None],
#  ['2017-12-22', 102.412, 103.479, 102.412, 102.958, 179.0, None, None],
#  ['2017-12-21', 101.055, 101.055, 101.055, 101.055, 0.0, None, None],
#  ['2017-12-20', 101.724, 102.1, 101.724, 102.1, 150.0, None, None],
#  ['2017-12-19', 102.033, 102.586, 101.609, 102.586, 140.0, None, None],
#  ['2017-12-18', 102.161, 103.45, 102.161, 103.45, 47.0, None, None],
#  ['2017-12-15', 100.436, 100.436, 100.436, 100.436, 0.0, None, None],
#  ['2017-12-14', 100.256, 100.256, 100.256, 100.256, 0.0, None, None],
#  ['2017-12-13', 101.166, 101.166, 101.166, 101.166, 0.0, None, None],
#  ['2017-12-12', 102.65, 102.65, 102.2, 102.2, 110.0, None, None],
#  ['2017-12-11', 103.264, 104.247, 103.264, 104.247, 50.0, None, None],
#  ['2017-12-08', 102.65, 102.65, 102.65, 102.65, 0.0, None, None],
#  ['2017-12-07', 102.013, 102.013, 102.013, 102.013, 0.0, None, None],
#  ['2017-12-06', 100.777, 102.45, 100.777, 102.45, 100.0, None, None],
#  ['2017-12-05', 100.499, 100.499, 100.499, 100.499, 0.0, None, None],
#  ['2017-12-04', 101.5, 101.5, 101.5, 101.5, 264.0, None, None],
#  ['2017-12-01', 100.393, 100.393, 100.393, 100.393, 0.0, None, None],
#  ['2017-11-30', 100.946, 101.6, 99.985, 99.985, 424.0, None, None],
#  ['2017-11-29', 101.211, 101.211, 101.211, 101.211, 0.0, None, None],
#  ['2017-11-28', 101.695, 101.695, 101.695, 101.695, 60.0, None, None],
#  ['2017-11-27', 100.536, 101.898, 100.536, 101.8, 140.0, None, None],
#  ['2017-11-24', 100.274, 100.274, 100.274, 100.274, 0.0, None, None],
#  ['2017-11-23', 100.705, 101.888, 100.55, 101.35, 800.0, None, None],
#  ['2017-11-22', 102.9, 102.9, 102.9, 102.9, 50.0, None, None],
#  ['2017-11-21', 103.087, 103.6, 102.983, 102.983, 181.0, None, None],
#  ['2017-11-20', 103.213, 103.6, 102.9, 102.9, 140.0, None, None],
#  ['2017-11-17', 104.204, 104.204, 104.204, 104.204, 0.0, None, None],
#  ['2017-11-16', 103.279, 104.964, 103.279, 104.964, 14.0, None, None],
#  ['2017-11-15', 104.785, 104.785, 104.785, 104.785, 0.0, None, None],
#  ['2017-11-14', 104.663, 105.6, 104.663, 105.6, 50.0, None, None],
#  ['2017-11-13', 105.5, 105.6, 105.5, 105.5, 500.0, None, None],
#  ['2017-11-10', 105.5, 105.5, 105.5, 105.5, 0.0, None, None],
#  ['2017-11-09', 106.59, 106.59, 106.59, 106.59, 0.0, None, None],
#  ['2017-11-08', 106.284, 106.284, 106.284, 106.284, 0.0, None, None],
#  ['2017-11-07', 108.788, 108.788, 108.3, 108.3, 80.0, None, None],
#  ['2017-11-06', 107.707, 109.2, 107.707, 108.95, 250.0, None, None],
#  ['2017-11-03', 105.44, 108.017, 105.44, 108.017, 230.0, None, None],
#  ['2017-11-02', 107.3, 107.3, 107.3, 107.3, 300.0, None, None],
#  ['2017-11-01', 106.3, 106.3, 106.3, 106.3, 0.0, None, None],
#  ['2017-10-31', 106.838, 106.838, 106.838, 106.838, 0.0, None, None],
#  ['2017-10-30', 108.198, 108.198, 106.838, 106.838, 16.0, None, None],
#  ['2017-10-27', 106.033, 107.4, 106.033, 107.4, 12.0, None, None],
#  ['2017-10-26', 106.3, 106.5, 106.3, 106.5, 34.0, None, None],
#  ['2017-10-25', 105.737, 106.505, 105.73, 105.73, 70.0, None, None],
#  ['2017-10-24', 107.14, 107.14, 107.14, 107.14, 0.0, None, None],
#  ['2017-10-23', 107.814, 109.1, 107.814, 109.1, 100.0, None, None],
#  ['2017-10-20', 106.995, 108.15, 106.995, 108.15, 45.0, None, None],
#  ['2017-10-19', 108.534, 109.887, 108.534, 108.7, 258.0, None, None],
#  ['2017-10-18', 107.837, 109.093, 107.837, 109.093, 20.0, None, None],
#  ['2017-10-17', 108.32, 108.65, 108.32, 108.65, 50.0, None, None],
#  ['2017-10-16', 107.687, 107.687, 107.6, 107.6, 150.0, None, None],
#  ['2017-10-13', 107.0, 107.0, 106.0, 106.45, 340.0, None, None],
#  ['2017-10-12', 107.85, 109.11, 107.85, 108.1, 300.0, None, None],
#  ['2017-10-11', 107.215, 108.037, 106.6, 106.6, 143.0, None, None],
#  ['2017-10-10', 109.0, 109.0, 107.754, 107.754, 212.0, None, None],
#  ['2017-10-09', 107.856, 109.0, 107.856, 108.448, 190.0, None, None],
#  ['2017-10-06', 109.0, 109.0, 108.418, 109.0, 83.0, None, None],
#  ['2017-10-05', 106.956, 109.133, 106.956, 109.133, 110.0, None, None],
#  ['2017-10-04', 106.881, 108.15, 106.881, 108.15, 111.0, None, None],
#  ['2017-10-03', 107.44, 107.44, 107.44, 107.44, 0.0, None, None],
#  ['2017-10-02', 107.002, 107.44, 107.002, 107.44, 258.0, None, None],
#  ['2017-09-29', 104.95, 105.65, 104.95, 105.65, 20.0, None, None],
#  ['2017-09-28', 104.347, 106.1, 104.347, 105.7, 190.0, None, None],
#  ['2017-09-27', 103.457, 104.35, 103.457, 104.25, 1368.0, None, None],
#  ['2017-09-26', 106.2, 106.5, 103.5, 104.0, 340.0, None, None],
#  ['2017-09-25', 111.027, 111.027, 107.5, 108.8, 261.0, None, None],
#  ['2017-09-22', 111.56, 111.56, 111.35, 111.35, 200.0, None, None],
#  ['2017-09-21', 111.983, 112.05, 111.983, 112.05, 36.0, None, None],
#  ['2017-09-20', 111.726, 113.0, 111.726, 113.0, 80.0, None, None],
#  ['2017-09-19', 111.41, 112.55, 111.41, 112.55, 30.0, None, None],
#  ['2017-09-18', 109.1, 110.75, 109.1, 110.75, 190.0, None, None],
#  ['2017-09-15', 108.461, 109.65, 108.461, 109.65, 91.0, None, None],
#  ['2017-09-14', 110.684, 110.684, 109.9, 109.9, 10.0, None, None],
#  ['2017-09-13', 111.43, 113.2, 111.43, 113.2, 0.0, None, None],
#  ['2017-09-12', 108.547, 108.547, 108.547, 108.547, 0.0, None, None],
#  ['2017-09-11', 109.075, 111.6, 109.075, 111.34, 93.0, None, None],
#  ['2017-09-08', 110.884, 110.884, 110.884, 110.884, 0.0, None, None],
#  ['2017-09-07', 113.0, 113.25, 113.0, 113.25, 70.0, None, None],
#  ['2017-09-06', 112.573, 113.9, 112.573, 113.9, 20.0, None, None],
#  ['2017-09-05', 111.5, 111.5, 111.5, 111.5, 0.0, None, None],
#  ['2017-09-04', 112.0, 112.0, 111.5, 111.5, 140.0, None, None],
#  ['2017-09-01', 107.5, 111.4, 107.5, 111.4, 40.0, None, None],
#  ['2017-08-31', 106.377, 109.87, 106.377, 109.87, 20.0, None, None],
#  ['2017-08-30', 104.54, 110.65, 104.54, 110.65, 160.0, None, None],
#  ['2017-08-29', 105.5, 106.0, 105.0, 105.0, 247.0, None, None],
#  ['2017-08-28', 107.24, 107.24, 107.2, 107.2, 70.0, None, None],
#  ['2017-08-25', 107.638, 108.875, 107.638, 108.875, 20.0, None, None],
#  ['2017-08-24', 110.0, 110.447, 107.75, 110.447, 159.0, None, None],
#  ['2017-08-23', 109.132, 109.132, 109.132, 109.132, 0.0, None, None],
#  ['2017-08-22', 109.132, 109.132, 109.132, 109.132, 0.0, None, None],
#  ['2017-08-21', 111.0, 111.0, 111.0, 111.0, 1.0, None, None],
#  ['2017-08-18', 112.5, 112.5, 112.45, 112.45, 45.0, None, None],
#  ['2017-08-17', 112.95, 112.95, 112.95, 112.95, 10.0, None, None],
#  ['2017-08-16', 112.2, 114.255, 112.2, 114.255, 12.0, None, None],
#  ['2017-08-15', 112.2, 112.3, 112.2, 112.3, 48.0, None, None],
#  ['2017-08-14', 109.883, 114.0, 109.883, 114.0, 90.0, None, None],
#  ['2017-08-11', 114.284, 114.284, 114.284, 114.284, 50.0, None, None],
#  ['2017-08-10', 109.718, 112.5, 109.718, 111.476, 65.0, None, None],
#  ['2017-08-09', 115.226, 115.226, 112.51, 112.51, 179.0, None, None],
#  ['2017-08-08', 112.51, 112.51, 112.51, 112.51, 0.0, None, None],
#  ['2017-08-07', 116.801, 116.801, 114.0, 114.149, 276.0, None, None],
#  ['2017-08-04', 113.75, 115.75, 113.75, 115.75, 365.0, None, None],
#  ['2017-08-03', 113.75, 115.0, 113.75, 115.0, 146.0, None, None],
#  ['2017-08-02', 112.51, 115.078, 112.51, 115.078, 9.0, None, None],
#  ['2017-08-01', 112.56, 114.787, 112.56, 114.787, 10.0, None, None],
#  ['2017-07-31', 115.477, 115.749, 113.0, 114.95, 1866.0, None, None],
#  ['2017-07-28', 111.012, 114.5, 111.012, 114.5, 699.0, None, None],
#  ['2017-07-27', 112.467, 115.749, 111.839, 115.749, 280.0, None, None],
#  ['2017-07-26', 115.749, 115.749, 114.5, 114.5, 51.0, None, None],
#  ['2017-07-25', 113.158, 113.158, 113.158, 113.158, 0.0, None, None],
#  ['2017-07-24', 112.972, 114.95, 112.972, 114.95, 75.0, None, None],
#  ['2017-07-21', 112.485, 115.7, 112.485, 114.084, 40.0, None, None],
#  ['2017-07-20', 117.0, 117.0, 115.0, 115.528, 122.0, None, None],
#  ['2017-07-19', 111.306, 114.85, 111.306, 114.85, 240.0, None, None],
#  ['2017-07-18', 109.813, 114.0, 109.813, 114.0, 100.0, None, None],
#  ['2017-07-17', 110.981, 113.5, 110.981, 112.25, 265.0, None, None],
#  ['2017-07-14', 110.194, 110.194, 110.194, 110.194, 0.0, 0.963857, 17.0],
#  ['2017-07-13', 110.671, 110.671, 110.671, 110.671, 0.0, None, None],
#  ['2017-07-12', 114.369, 114.369, 112.6, 112.6, 122.0, None, None],
#  ['2017-07-11', 112.847, 116.5, 112.847, 115.2, 58.0, None, None],
#  ['2017-07-10', 111.996, 111.996, 111.996, 111.996, 0.0, None, None],
#  ['2017-07-07', 111.381, 111.381, 111.381, 111.381, 0.0, None, None],
#  ['2017-07-06', 112.401, 114.9, 112.401, 114.9, 28.0, None, None],
#  ['2017-07-05', 112.388, 113.7, 112.388, 113.0, 270.0, None, None],
#  ['2017-07-04', 112.851, 112.851, 112.851, 112.851, 0.0, None, None],
#  ['2017-07-03', 116.897, 116.897, 114.25, 115.8, 331.0, None, None],
#  ['2017-06-30', 110.65, 114.3, 110.65, 114.3, 215.0, None, None],
#  ['2017-06-29', 112.001, 114.2, 112.001, 113.8, 140.0, None, None],
#  ['2017-06-28', 114.55, 114.55, 114.55, 114.55, 0.0, None, None],
#  ['2017-06-27', 112.623, 115.45, 112.623, 114.55, 45.0, None, None],
#  ['2017-06-26', 111.327, 114.246, 111.327, 114.246, 20.0, None, None],
#  ['2017-06-23', 110.868, 112.554, 110.868, 112.0, 149.0, None, None],
#  ['2017-06-22', 110.65, 113.262, 110.65, 113.178, 118.0, None, None],
#  ['2017-06-21', 110.65, 114.387, 110.65, 114.387, 51.0, None, None],
#  ['2017-06-20', 106.0, 113.0, 106.0, 112.007, 590.0, None, None],
#  ['2017-06-19', 108.0, 108.2, 107.5, 107.5, 75.0, None, None],
#  ['2017-06-16', 109.3, 109.3, 106.8, 106.8, 613.0, None, None],
#  ['2017-06-15', 106.95, 107.5, 106.95, 107.5, 90.0, None, None],
#  ['2017-06-14', 105.255, 107.0, 105.255, 107.0, 50.0, None, None],
#  ['2017-06-13', 104.604, 107.69, 104.604, 107.69, 181.0, None, None],
#  ['2017-06-12', 110.0, 110.0, 107.0, 107.0, 400.0, None, None],
#  ['2017-06-09', 105.5, 108.3, 105.5, 108.3, 25.0, None, None],
#  ['2017-06-08', 104.25, 104.25, 104.25, 104.25, 0.0, None, None],
#  ['2017-06-07', 101.509, 106.5, 101.509, 104.171, 40.0, None, None],
#  ['2017-06-06', 101.682, 104.577, 101.682, 104.577, 100.0, None, None],
#  ['2017-06-05', 101.434, 101.434, 101.434, 101.434, 0.0, None, None],
#  ['2017-06-02', 101.434, 101.434, 101.434, 101.434, 0.0, None, None],
#  ['2017-06-01', 100.688, 100.688, 100.688, 100.688, 0.0, None, None],
#  ['2017-05-31', 101.144, 103.546, 101.144, 101.276, 130.0, None, None],
#  ['2017-05-30', 101.652, 104.15, 101.5, 101.5, 51.0, None, None],
#  ['2017-05-29', 103.91, 103.911, 103.91, 103.91, 170.0, None, None],
#  ['2017-05-26', 101.812, 105.0, 101.812, 103.9, 442.0, None, None],
#  ['2017-05-25', 100.932, 104.806, 100.932, 104.806, 25.0, None, None],
#  ['2017-05-24', 100.733, 101.5, 100.733, 101.5, 44.0, None, None],
#  ['2017-05-23', 100.0, 103.445, 100.0, 103.445, 25.0, None, None],
#  ['2017-05-22', 100.096, 103.688, 100.096, 103.688, 260.0, None, None],
#  ['2017-05-19', 100.178, 102.266, 100.178, 102.0, 3700.0, None, None],
#  ['2017-05-18', 103.601, 103.7, 101.0, 101.244, 175.0, None, None],
#  ['2017-05-17', 100.741, 104.75, 100.741, 102.5, 575.0, None, None],
#  ['2017-05-16', 103.7, 104.3, 103.7, 104.0, 190.0, None, None],
#  ['2017-05-15', 101.252, 105.05, 101.252, 104.4, 119.0, None, None],
#  ['2017-05-12', 102.0, 106.35, 102.0, 103.7, 316.0, None, None],
#  ['2017-05-11', 98.069, 100.2, 98.069, 100.2, 34.0, None, None],
#  ['2017-05-10', 97.136, 99.84, 97.136, 99.84, 5.0, None, None],
#  ['2017-05-09', 99.753, 100.2, 99.753, 100.0, 130.0, None, None],
#  ['2017-05-08', 95.403, 98.93, 95.403, 98.93, 175.0, None, None],
#  ['2017-05-05', 95.445, 97.9, 95.445, 97.9, 44.0, None, None],
#  ['2017-05-04', 94.752, 98.474, 94.752, 98.474, 15.0, None, None],
#  ['2017-05-03', 95.05, 96.5, 95.05, 96.5, 40.0, None, None],
#  ['2017-05-02', 94.802, 97.96, 94.802, 96.02, 340.0, None, None],
#  ['2017-05-01', 95.006, 95.006, 95.006, 95.006, 0.0, None, None],
#  ['2017-04-28', 95.006, 95.006, 95.006, 95.006, 0.0, None, None],
#  ['2017-04-27', 94.709, 97.49, 94.709, 97.49, 17.0, None, None],
#  ['2017-04-26', 94.6, 97.46, 94.5, 97.46, 246.0, None, None],
#  ['2017-04-25', 92.585, 94.313, 92.585, 94.313, 590.0, None, None],
#  ['2017-04-24', 92.1, 92.1, 92.1, 92.1, 0.0, None, None],
#  ['2017-04-21', 92.1, 93.3, 92.1, 92.99, 155.0, None, None],
#  ['2017-04-20', 91.0, 91.0, 91.0, 91.0, 0.0, None, None],
#  ['2017-04-19', 94.0, 94.0, 94.0, 94.0, 0.0, None, None],
#  ['2017-04-18', 94.0, 94.83, 94.0, 94.0, 257.0, None, None],
#  ['2017-04-17', 93.16, 93.16, 93.16, 93.16, 0.0, None, None],
#  ['2017-04-14', 93.16, 93.16, 93.16, 93.16, 0.0, None, None],
#  ['2017-04-13', 91.869, 94.143, 91.869, 93.16, 200.0, None, None],
#  ['2017-04-12', 95.0, 95.0, 94.212, 94.515, 90.0, None, None],
#  ['2017-04-11', 95.84, 95.84, 95.6, 95.6, 134.0, None, None],
#  ['2017-04-10', 95.84, 96.908, 95.84, 96.908, 10.0, None, None],
#  ['2017-04-07', 95.75, 95.75, 95.633, 95.633, 30.0, None, None],
#  ['2017-04-06', 96.3, 96.6, 96.3, 96.6, 38.0, None, None],
#  ['2017-04-05', 95.0, 97.5, 95.0, 96.8, 65.0, None, None],
#  ['2017-04-04', 98.8, 98.8, 97.99, 97.99, 50.0, None, None],
#  ['2017-04-03', 98.0, 98.0, 98.0, 98.0, 30.0, None, None],
#  ['2017-03-31', 98.342, 100.75, 98.342, 100.31, 260.0, None, None],
#  ['2017-03-30', 99.8, 100.75, 99.8, 100.75, 55.0, None, None],
#  ['2017-03-29', 102.571, 102.571, 101.332, 101.332, 39.0, None, None],
#  ['2017-03-28', 98.357, 98.357, 98.357, 98.357, 0.0, None, None],
#  ['2017-03-27', 98.585, 98.585, 98.585, 98.585, 0.0, None, None],
#  ['2017-03-24', 97.911, 97.911, 97.911, 97.911, 0.0, None, None],
#  ['2017-03-23', 99.525, 100.329, 99.525, 100.329, 100.0, None, None],
#  ['2017-03-22', 102.5, 102.5, 102.5, 102.5, 70.0, None, None],
#  ['2017-03-21', 102.5, 102.5, 102.5, 102.5, 0.0, None, None],
#  ['2017-03-20', 101.939, 101.939, 101.939, 101.939, 0.0, None, None],
#  ['2017-03-17', 101.835, 101.835, 101.835, 101.835, 0.0, None, None],
#  ['2017-03-16', 102.262, 105.35, 102.262, 104.5, 93.0, None, None],
#  ['2017-03-15', 103.475, 103.475, 103.475, 103.475, 0.0, None, None],
#  ['2017-03-14', 103.828, 103.828, 103.828, 103.828, 0.0, None, None],
#  ['2017-03-13', 107.628, 107.628, 106.7, 106.7, 203.0, None, None],
#  ['2017-03-10', 103.957, 106.037, 103.874, 103.874, 51.0, None, None],
#  ['2017-03-09', 103.65, 103.65, 103.65, 103.65, 9.0, None, None],
#  ['2017-03-08', 104.127, 105.1, 104.127, 105.1, 13.0, None, None],
#  ['2017-03-07', 104.384, 107.3, 104.384, 107.3, 15.0, None, None],
#  ['2017-03-06', 104.589, 106.95, 104.589, 106.95, 10.0, None, None],
#  ['2017-03-03', 104.414, 104.414, 104.414, 104.414, 0.0, None, None],
#  ['2017-03-02', 107.0, 107.45, 107.0, 107.45, 71.0, None, None],
#  ['2017-03-01', 104.143, 108.0, 104.143, 108.0, 11.0, None, None],
#  ['2017-02-28', 104.658, 104.658, 104.658, 104.658, 0.0, None, None],
#  ['2017-02-27', 105.457, 105.457, 105.457, 105.457, 0.0, None, None],
#  ['2017-02-24', 109.0, 109.0, 108.0, 108.0, 330.0, None, None],
#  ['2017-02-23', 105.383, 109.125, 105.383, 109.125, 151.0, None, None],
#  ['2017-02-22', 105.484, 105.484, 105.484, 105.484, 0.0, None, None],
#  ['2017-02-21', 108.9, 108.9, 107.699, 107.699, 100.0, None, None],
#  ['2017-02-20', 105.869, 108.301, 105.869, 107.2, 137.0, None, None],
#  ['2017-02-17', 104.187, 107.5, 104.187, 107.5, 50.0, None, None],
#  ['2017-02-16', 103.006, 107.0, 103.006, 105.468, 200.0, None, None],
#  ['2017-02-15', 102.779, 105.627, 102.779, 105.627, 150.0, None, None],
#  ['2017-02-14', 102.792, 105.4, 102.792, 105.3, 178.0, None, None],
#  ['2017-02-13', 104.5, 105.5, 103.4, 105.5, 152.0, None, None],
#  ['2017-02-10', 102.5, 103.9, 102.5, 103.0, 95.0, None, None],
#  ['2017-02-09', 102.5, 103.55, 102.5, 103.55, 50.0, None, None],
#  ['2017-02-08', 101.375, 101.375, 101.375, 101.375, 0.0, None, None],
#  ['2017-02-07', 101.0, 104.935, 101.0, 104.1, 66.0, None, None],
#  ['2017-02-06', 100.925, 104.1, 100.925, 103.5, 65.0, None, None],
#  ['2017-02-03', 102.868, 106.974, 102.1, 103.0, 376.0, None, None],
#  ['2017-02-02', 105.627, 105.627, 104.3, 104.95, 201.0, 1.0, 3.0],
#  ['2017-02-01', 114.658, 114.658, 103.3, 107.45, 1162.0, None, None],
#  ['2017-01-31', 118.38, 118.38, 115.282, 115.282, 150.0, None, None],
#  ['2017-01-30', 118.992, 118.992, 118.992, 118.992, 0.0, None, None],
#  ['2017-01-27', 118.36, 123.409, 118.36, 123.409, 40.0, None, None],
#  ['2017-01-26', 123.108, 123.108, 123.108, 123.108, 0.0, None, None],
#  ['2017-01-25', 119.95, 119.95, 119.95, 119.95, 0.0, None, None],
#  ['2017-01-24', 120.437, 122.0, 120.437, 122.0, 13.0, None, None],
#  ['2017-01-23', 120.034, 120.034, 120.034, 120.034, 0.0, None, None],
#  ['2017-01-20', 120.554, 120.554, 120.554, 120.554, 0.0, None, None],
#  ['2017-01-19', 121.776, 121.776, 121.776, 121.776, 0.0, None, None],
#  ['2017-01-18', 122.296, 123.8, 122.296, 123.8, 16.0, None, None],
#  ['2017-01-17', 126.0, 126.0, 123.55, 125.4, 119.0, None, None],
#  ['2017-01-16', 121.533, 125.6, 121.533, 125.6, 24.0, None, None],
#  ['2017-01-13', 116.483, 126.788, 116.483, 126.788, 106.0, None, None],
#  ['2017-01-12', 114.038, 118.25, 114.038, 118.25, 150.0, None, None],
#  ['2017-01-11', 114.048, 117.85, 114.048, 117.85, 40.0, None, None],
#  ['2017-01-10', 113.095, 113.095, 113.095, 113.095, 0.0, None, None],
#  ['2017-01-09', 113.97, 113.97, 113.97, 113.97, 0.0, None, None],
#  ['2017-01-06', 113.849, 113.849, 113.849, 113.849, 0.0, None, None],
#  ['2017-01-05', 113.234, 113.234, 113.234, 113.234, 0.0, None, None],
#  ['2017-01-04', 113.0, 113.0, 113.0, 113.0, 0.0, None, None],
#  ['2017-01-03', 113.0, 113.0, 113.0, 113.0, 0.0, None, None],
#  ['2017-01-02', 114.65, 114.65, 114.36, 114.36, 30.0, None, None]]

# %%
json_data['dataset']['column_names']
# Out:
# ['Date',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Adjustment Factor',
#  'Adjustment Type']

# %%
dset = {}
for entry in json_data['dataset']['data']:
    dset[entry[0]] = dict(zip(json_data['dataset']['column_names'][1:], entry[1:]))

# %%
dset
# Out:
# {'2017-12-29': {'Open': 103.333,
#   'High': 103.999,
#   'Low': 103.288,
#   'Close': 103.288,
#   'Volume': 310.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-28': {'Open': 102.389,
#   'High': 102.389,
#   'Low': 102.389,
#   'Close': 102.389,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-27': {'Open': 102.574,
#   'High': 103.6,
#   'Low': 102.574,
#   'Close': 103.6,
#   'Volume': 404.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-26': {'Open': 102.958,
#   'High': 102.958,
#   'Low': 102.958,
#   'Close': 102.958,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-25': {'Open': 102.958,
#   'High': 102.958,
#   'Low': 102.958,
#   'Close': 102.958,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-22': {'Open': 102.412,
#   'High': 103.479,
#   'Low': 102.412,
#   'Close': 102.958,
#   'Volume': 179.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-21': {'Open': 101.055,
#   'High': 101.055,
#   'Low': 101.055,
#   'Close': 101.055,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-20': {'Open': 101.724,
#   'High': 102.1,
#   'Low': 101.724,
#   'Close': 102.1,
#   'Volume': 150.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-19': {'Open': 102.033,
#   'High': 102.586,
#   'Low': 101.609,
#   'Close': 102.586,
#   'Volume': 140.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-18': {'Open': 102.161,
#   'High': 103.45,
#   'Low': 102.161,
#   'Close': 103.45,
#   'Volume': 47.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-15': {'Open': 100.436,
#   'High': 100.436,
#   'Low': 100.436,
#   'Close': 100.436,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-14': {'Open': 100.256,
#   'High': 100.256,
#   'Low': 100.256,
#   'Close': 100.256,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-13': {'Open': 101.166,
#   'High': 101.166,
#   'Low': 101.166,
#   'Close': 101.166,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-12': {'Open': 102.65,
#   'High': 102.65,
#   'Low': 102.2,
#   'Close': 102.2,
#   'Volume': 110.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-11': {'Open': 103.264,
#   'High': 104.247,
#   'Low': 103.264,
#   'Close': 104.247,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-08': {'Open': 102.65,
#   'High': 102.65,
#   'Low': 102.65,
#   'Close': 102.65,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-07': {'Open': 102.013,
#   'High': 102.013,
#   'Low': 102.013,
#   'Close': 102.013,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-06': {'Open': 100.777,
#   'High': 102.45,
#   'Low': 100.777,
#   'Close': 102.45,
#   'Volume': 100.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-05': {'Open': 100.499,
#   'High': 100.499,
#   'Low': 100.499,
#   'Close': 100.499,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-04': {'Open': 101.5,
#   'High': 101.5,
#   'Low': 101.5,
#   'Close': 101.5,
#   'Volume': 264.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-12-01': {'Open': 100.393,
#   'High': 100.393,
#   'Low': 100.393,
#   'Close': 100.393,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-30': {'Open': 100.946,
#   'High': 101.6,
#   'Low': 99.985,
#   'Close': 99.985,
#   'Volume': 424.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-29': {'Open': 101.211,
#   'High': 101.211,
#   'Low': 101.211,
#   'Close': 101.211,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-28': {'Open': 101.695,
#   'High': 101.695,
#   'Low': 101.695,
#   'Close': 101.695,
#   'Volume': 60.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-27': {'Open': 100.536,
#   'High': 101.898,
#   'Low': 100.536,
#   'Close': 101.8,
#   'Volume': 140.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-24': {'Open': 100.274,
#   'High': 100.274,
#   'Low': 100.274,
#   'Close': 100.274,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-23': {'Open': 100.705,
#   'High': 101.888,
#   'Low': 100.55,
#   'Close': 101.35,
#   'Volume': 800.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-22': {'Open': 102.9,
#   'High': 102.9,
#   'Low': 102.9,
#   'Close': 102.9,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-21': {'Open': 103.087,
#   'High': 103.6,
#   'Low': 102.983,
#   'Close': 102.983,
#   'Volume': 181.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-20': {'Open': 103.213,
#   'High': 103.6,
#   'Low': 102.9,
#   'Close': 102.9,
#   'Volume': 140.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-17': {'Open': 104.204,
#   'High': 104.204,
#   'Low': 104.204,
#   'Close': 104.204,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-16': {'Open': 103.279,
#   'High': 104.964,
#   'Low': 103.279,
#   'Close': 104.964,
#   'Volume': 14.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-15': {'Open': 104.785,
#   'High': 104.785,
#   'Low': 104.785,
#   'Close': 104.785,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-14': {'Open': 104.663,
#   'High': 105.6,
#   'Low': 104.663,
#   'Close': 105.6,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-13': {'Open': 105.5,
#   'High': 105.6,
#   'Low': 105.5,
#   'Close': 105.5,
#   'Volume': 500.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-10': {'Open': 105.5,
#   'High': 105.5,
#   'Low': 105.5,
#   'Close': 105.5,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-09': {'Open': 106.59,
#   'High': 106.59,
#   'Low': 106.59,
#   'Close': 106.59,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-08': {'Open': 106.284,
#   'High': 106.284,
#   'Low': 106.284,
#   'Close': 106.284,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-07': {'Open': 108.788,
#   'High': 108.788,
#   'Low': 108.3,
#   'Close': 108.3,
#   'Volume': 80.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-06': {'Open': 107.707,
#   'High': 109.2,
#   'Low': 107.707,
#   'Close': 108.95,
#   'Volume': 250.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-03': {'Open': 105.44,
#   'High': 108.017,
#   'Low': 105.44,
#   'Close': 108.017,
#   'Volume': 230.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-02': {'Open': 107.3,
#   'High': 107.3,
#   'Low': 107.3,
#   'Close': 107.3,
#   'Volume': 300.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-11-01': {'Open': 106.3,
#   'High': 106.3,
#   'Low': 106.3,
#   'Close': 106.3,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-31': {'Open': 106.838,
#   'High': 106.838,
#   'Low': 106.838,
#   'Close': 106.838,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-30': {'Open': 108.198,
#   'High': 108.198,
#   'Low': 106.838,
#   'Close': 106.838,
#   'Volume': 16.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-27': {'Open': 106.033,
#   'High': 107.4,
#   'Low': 106.033,
#   'Close': 107.4,
#   'Volume': 12.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-26': {'Open': 106.3,
#   'High': 106.5,
#   'Low': 106.3,
#   'Close': 106.5,
#   'Volume': 34.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-25': {'Open': 105.737,
#   'High': 106.505,
#   'Low': 105.73,
#   'Close': 105.73,
#   'Volume': 70.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-24': {'Open': 107.14,
#   'High': 107.14,
#   'Low': 107.14,
#   'Close': 107.14,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-23': {'Open': 107.814,
#   'High': 109.1,
#   'Low': 107.814,
#   'Close': 109.1,
#   'Volume': 100.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-20': {'Open': 106.995,
#   'High': 108.15,
#   'Low': 106.995,
#   'Close': 108.15,
#   'Volume': 45.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-19': {'Open': 108.534,
#   'High': 109.887,
#   'Low': 108.534,
#   'Close': 108.7,
#   'Volume': 258.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-18': {'Open': 107.837,
#   'High': 109.093,
#   'Low': 107.837,
#   'Close': 109.093,
#   'Volume': 20.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-17': {'Open': 108.32,
#   'High': 108.65,
#   'Low': 108.32,
#   'Close': 108.65,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-16': {'Open': 107.687,
#   'High': 107.687,
#   'Low': 107.6,
#   'Close': 107.6,
#   'Volume': 150.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-13': {'Open': 107.0,
#   'High': 107.0,
#   'Low': 106.0,
#   'Close': 106.45,
#   'Volume': 340.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-12': {'Open': 107.85,
#   'High': 109.11,
#   'Low': 107.85,
#   'Close': 108.1,
#   'Volume': 300.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-11': {'Open': 107.215,
#   'High': 108.037,
#   'Low': 106.6,
#   'Close': 106.6,
#   'Volume': 143.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-10': {'Open': 109.0,
#   'High': 109.0,
#   'Low': 107.754,
#   'Close': 107.754,
#   'Volume': 212.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-09': {'Open': 107.856,
#   'High': 109.0,
#   'Low': 107.856,
#   'Close': 108.448,
#   'Volume': 190.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-06': {'Open': 109.0,
#   'High': 109.0,
#   'Low': 108.418,
#   'Close': 109.0,
#   'Volume': 83.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-05': {'Open': 106.956,
#   'High': 109.133,
#   'Low': 106.956,
#   'Close': 109.133,
#   'Volume': 110.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-04': {'Open': 106.881,
#   'High': 108.15,
#   'Low': 106.881,
#   'Close': 108.15,
#   'Volume': 111.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-03': {'Open': 107.44,
#   'High': 107.44,
#   'Low': 107.44,
#   'Close': 107.44,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-10-02': {'Open': 107.002,
#   'High': 107.44,
#   'Low': 107.002,
#   'Close': 107.44,
#   'Volume': 258.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-29': {'Open': 104.95,
#   'High': 105.65,
#   'Low': 104.95,
#   'Close': 105.65,
#   'Volume': 20.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-28': {'Open': 104.347,
#   'High': 106.1,
#   'Low': 104.347,
#   'Close': 105.7,
#   'Volume': 190.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-27': {'Open': 103.457,
#   'High': 104.35,
#   'Low': 103.457,
#   'Close': 104.25,
#   'Volume': 1368.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-26': {'Open': 106.2,
#   'High': 106.5,
#   'Low': 103.5,
#   'Close': 104.0,
#   'Volume': 340.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-25': {'Open': 111.027,
#   'High': 111.027,
#   'Low': 107.5,
#   'Close': 108.8,
#   'Volume': 261.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-22': {'Open': 111.56,
#   'High': 111.56,
#   'Low': 111.35,
#   'Close': 111.35,
#   'Volume': 200.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-21': {'Open': 111.983,
#   'High': 112.05,
#   'Low': 111.983,
#   'Close': 112.05,
#   'Volume': 36.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-20': {'Open': 111.726,
#   'High': 113.0,
#   'Low': 111.726,
#   'Close': 113.0,
#   'Volume': 80.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-19': {'Open': 111.41,
#   'High': 112.55,
#   'Low': 111.41,
#   'Close': 112.55,
#   'Volume': 30.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-18': {'Open': 109.1,
#   'High': 110.75,
#   'Low': 109.1,
#   'Close': 110.75,
#   'Volume': 190.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-15': {'Open': 108.461,
#   'High': 109.65,
#   'Low': 108.461,
#   'Close': 109.65,
#   'Volume': 91.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-14': {'Open': 110.684,
#   'High': 110.684,
#   'Low': 109.9,
#   'Close': 109.9,
#   'Volume': 10.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-13': {'Open': 111.43,
#   'High': 113.2,
#   'Low': 111.43,
#   'Close': 113.2,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-12': {'Open': 108.547,
#   'High': 108.547,
#   'Low': 108.547,
#   'Close': 108.547,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-11': {'Open': 109.075,
#   'High': 111.6,
#   'Low': 109.075,
#   'Close': 111.34,
#   'Volume': 93.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-08': {'Open': 110.884,
#   'High': 110.884,
#   'Low': 110.884,
#   'Close': 110.884,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-07': {'Open': 113.0,
#   'High': 113.25,
#   'Low': 113.0,
#   'Close': 113.25,
#   'Volume': 70.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-06': {'Open': 112.573,
#   'High': 113.9,
#   'Low': 112.573,
#   'Close': 113.9,
#   'Volume': 20.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-05': {'Open': 111.5,
#   'High': 111.5,
#   'Low': 111.5,
#   'Close': 111.5,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-04': {'Open': 112.0,
#   'High': 112.0,
#   'Low': 111.5,
#   'Close': 111.5,
#   'Volume': 140.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-09-01': {'Open': 107.5,
#   'High': 111.4,
#   'Low': 107.5,
#   'Close': 111.4,
#   'Volume': 40.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-31': {'Open': 106.377,
#   'High': 109.87,
#   'Low': 106.377,
#   'Close': 109.87,
#   'Volume': 20.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-30': {'Open': 104.54,
#   'High': 110.65,
#   'Low': 104.54,
#   'Close': 110.65,
#   'Volume': 160.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-29': {'Open': 105.5,
#   'High': 106.0,
#   'Low': 105.0,
#   'Close': 105.0,
#   'Volume': 247.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-28': {'Open': 107.24,
#   'High': 107.24,
#   'Low': 107.2,
#   'Close': 107.2,
#   'Volume': 70.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-25': {'Open': 107.638,
#   'High': 108.875,
#   'Low': 107.638,
#   'Close': 108.875,
#   'Volume': 20.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-24': {'Open': 110.0,
#   'High': 110.447,
#   'Low': 107.75,
#   'Close': 110.447,
#   'Volume': 159.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-23': {'Open': 109.132,
#   'High': 109.132,
#   'Low': 109.132,
#   'Close': 109.132,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-22': {'Open': 109.132,
#   'High': 109.132,
#   'Low': 109.132,
#   'Close': 109.132,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-21': {'Open': 111.0,
#   'High': 111.0,
#   'Low': 111.0,
#   'Close': 111.0,
#   'Volume': 1.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-18': {'Open': 112.5,
#   'High': 112.5,
#   'Low': 112.45,
#   'Close': 112.45,
#   'Volume': 45.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-17': {'Open': 112.95,
#   'High': 112.95,
#   'Low': 112.95,
#   'Close': 112.95,
#   'Volume': 10.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-16': {'Open': 112.2,
#   'High': 114.255,
#   'Low': 112.2,
#   'Close': 114.255,
#   'Volume': 12.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-15': {'Open': 112.2,
#   'High': 112.3,
#   'Low': 112.2,
#   'Close': 112.3,
#   'Volume': 48.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-14': {'Open': 109.883,
#   'High': 114.0,
#   'Low': 109.883,
#   'Close': 114.0,
#   'Volume': 90.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-11': {'Open': 114.284,
#   'High': 114.284,
#   'Low': 114.284,
#   'Close': 114.284,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-10': {'Open': 109.718,
#   'High': 112.5,
#   'Low': 109.718,
#   'Close': 111.476,
#   'Volume': 65.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-09': {'Open': 115.226,
#   'High': 115.226,
#   'Low': 112.51,
#   'Close': 112.51,
#   'Volume': 179.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-08': {'Open': 112.51,
#   'High': 112.51,
#   'Low': 112.51,
#   'Close': 112.51,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-07': {'Open': 116.801,
#   'High': 116.801,
#   'Low': 114.0,
#   'Close': 114.149,
#   'Volume': 276.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-04': {'Open': 113.75,
#   'High': 115.75,
#   'Low': 113.75,
#   'Close': 115.75,
#   'Volume': 365.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-03': {'Open': 113.75,
#   'High': 115.0,
#   'Low': 113.75,
#   'Close': 115.0,
#   'Volume': 146.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-02': {'Open': 112.51,
#   'High': 115.078,
#   'Low': 112.51,
#   'Close': 115.078,
#   'Volume': 9.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-08-01': {'Open': 112.56,
#   'High': 114.787,
#   'Low': 112.56,
#   'Close': 114.787,
#   'Volume': 10.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-31': {'Open': 115.477,
#   'High': 115.749,
#   'Low': 113.0,
#   'Close': 114.95,
#   'Volume': 1866.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-28': {'Open': 111.012,
#   'High': 114.5,
#   'Low': 111.012,
#   'Close': 114.5,
#   'Volume': 699.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-27': {'Open': 112.467,
#   'High': 115.749,
#   'Low': 111.839,
#   'Close': 115.749,
#   'Volume': 280.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-26': {'Open': 115.749,
#   'High': 115.749,
#   'Low': 114.5,
#   'Close': 114.5,
#   'Volume': 51.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-25': {'Open': 113.158,
#   'High': 113.158,
#   'Low': 113.158,
#   'Close': 113.158,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-24': {'Open': 112.972,
#   'High': 114.95,
#   'Low': 112.972,
#   'Close': 114.95,
#   'Volume': 75.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-21': {'Open': 112.485,
#   'High': 115.7,
#   'Low': 112.485,
#   'Close': 114.084,
#   'Volume': 40.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-20': {'Open': 117.0,
#   'High': 117.0,
#   'Low': 115.0,
#   'Close': 115.528,
#   'Volume': 122.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-19': {'Open': 111.306,
#   'High': 114.85,
#   'Low': 111.306,
#   'Close': 114.85,
#   'Volume': 240.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-18': {'Open': 109.813,
#   'High': 114.0,
#   'Low': 109.813,
#   'Close': 114.0,
#   'Volume': 100.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-17': {'Open': 110.981,
#   'High': 113.5,
#   'Low': 110.981,
#   'Close': 112.25,
#   'Volume': 265.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-14': {'Open': 110.194,
#   'High': 110.194,
#   'Low': 110.194,
#   'Close': 110.194,
#   'Volume': 0.0,
#   'Adjustment Factor': 0.963857,
#   'Adjustment Type': 17.0},
#  '2017-07-13': {'Open': 110.671,
#   'High': 110.671,
#   'Low': 110.671,
#   'Close': 110.671,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-12': {'Open': 114.369,
#   'High': 114.369,
#   'Low': 112.6,
#   'Close': 112.6,
#   'Volume': 122.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-11': {'Open': 112.847,
#   'High': 116.5,
#   'Low': 112.847,
#   'Close': 115.2,
#   'Volume': 58.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-10': {'Open': 111.996,
#   'High': 111.996,
#   'Low': 111.996,
#   'Close': 111.996,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-07': {'Open': 111.381,
#   'High': 111.381,
#   'Low': 111.381,
#   'Close': 111.381,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-06': {'Open': 112.401,
#   'High': 114.9,
#   'Low': 112.401,
#   'Close': 114.9,
#   'Volume': 28.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-05': {'Open': 112.388,
#   'High': 113.7,
#   'Low': 112.388,
#   'Close': 113.0,
#   'Volume': 270.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-04': {'Open': 112.851,
#   'High': 112.851,
#   'Low': 112.851,
#   'Close': 112.851,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-07-03': {'Open': 116.897,
#   'High': 116.897,
#   'Low': 114.25,
#   'Close': 115.8,
#   'Volume': 331.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-30': {'Open': 110.65,
#   'High': 114.3,
#   'Low': 110.65,
#   'Close': 114.3,
#   'Volume': 215.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-29': {'Open': 112.001,
#   'High': 114.2,
#   'Low': 112.001,
#   'Close': 113.8,
#   'Volume': 140.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-28': {'Open': 114.55,
#   'High': 114.55,
#   'Low': 114.55,
#   'Close': 114.55,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-27': {'Open': 112.623,
#   'High': 115.45,
#   'Low': 112.623,
#   'Close': 114.55,
#   'Volume': 45.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-26': {'Open': 111.327,
#   'High': 114.246,
#   'Low': 111.327,
#   'Close': 114.246,
#   'Volume': 20.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-23': {'Open': 110.868,
#   'High': 112.554,
#   'Low': 110.868,
#   'Close': 112.0,
#   'Volume': 149.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-22': {'Open': 110.65,
#   'High': 113.262,
#   'Low': 110.65,
#   'Close': 113.178,
#   'Volume': 118.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-21': {'Open': 110.65,
#   'High': 114.387,
#   'Low': 110.65,
#   'Close': 114.387,
#   'Volume': 51.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-20': {'Open': 106.0,
#   'High': 113.0,
#   'Low': 106.0,
#   'Close': 112.007,
#   'Volume': 590.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-19': {'Open': 108.0,
#   'High': 108.2,
#   'Low': 107.5,
#   'Close': 107.5,
#   'Volume': 75.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-16': {'Open': 109.3,
#   'High': 109.3,
#   'Low': 106.8,
#   'Close': 106.8,
#   'Volume': 613.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-15': {'Open': 106.95,
#   'High': 107.5,
#   'Low': 106.95,
#   'Close': 107.5,
#   'Volume': 90.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-14': {'Open': 105.255,
#   'High': 107.0,
#   'Low': 105.255,
#   'Close': 107.0,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-13': {'Open': 104.604,
#   'High': 107.69,
#   'Low': 104.604,
#   'Close': 107.69,
#   'Volume': 181.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-12': {'Open': 110.0,
#   'High': 110.0,
#   'Low': 107.0,
#   'Close': 107.0,
#   'Volume': 400.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-09': {'Open': 105.5,
#   'High': 108.3,
#   'Low': 105.5,
#   'Close': 108.3,
#   'Volume': 25.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-08': {'Open': 104.25,
#   'High': 104.25,
#   'Low': 104.25,
#   'Close': 104.25,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-07': {'Open': 101.509,
#   'High': 106.5,
#   'Low': 101.509,
#   'Close': 104.171,
#   'Volume': 40.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-06': {'Open': 101.682,
#   'High': 104.577,
#   'Low': 101.682,
#   'Close': 104.577,
#   'Volume': 100.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-05': {'Open': 101.434,
#   'High': 101.434,
#   'Low': 101.434,
#   'Close': 101.434,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-02': {'Open': 101.434,
#   'High': 101.434,
#   'Low': 101.434,
#   'Close': 101.434,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-06-01': {'Open': 100.688,
#   'High': 100.688,
#   'Low': 100.688,
#   'Close': 100.688,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-31': {'Open': 101.144,
#   'High': 103.546,
#   'Low': 101.144,
#   'Close': 101.276,
#   'Volume': 130.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-30': {'Open': 101.652,
#   'High': 104.15,
#   'Low': 101.5,
#   'Close': 101.5,
#   'Volume': 51.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-29': {'Open': 103.91,
#   'High': 103.911,
#   'Low': 103.91,
#   'Close': 103.91,
#   'Volume': 170.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-26': {'Open': 101.812,
#   'High': 105.0,
#   'Low': 101.812,
#   'Close': 103.9,
#   'Volume': 442.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-25': {'Open': 100.932,
#   'High': 104.806,
#   'Low': 100.932,
#   'Close': 104.806,
#   'Volume': 25.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-24': {'Open': 100.733,
#   'High': 101.5,
#   'Low': 100.733,
#   'Close': 101.5,
#   'Volume': 44.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-23': {'Open': 100.0,
#   'High': 103.445,
#   'Low': 100.0,
#   'Close': 103.445,
#   'Volume': 25.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-22': {'Open': 100.096,
#   'High': 103.688,
#   'Low': 100.096,
#   'Close': 103.688,
#   'Volume': 260.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-19': {'Open': 100.178,
#   'High': 102.266,
#   'Low': 100.178,
#   'Close': 102.0,
#   'Volume': 3700.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-18': {'Open': 103.601,
#   'High': 103.7,
#   'Low': 101.0,
#   'Close': 101.244,
#   'Volume': 175.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-17': {'Open': 100.741,
#   'High': 104.75,
#   'Low': 100.741,
#   'Close': 102.5,
#   'Volume': 575.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-16': {'Open': 103.7,
#   'High': 104.3,
#   'Low': 103.7,
#   'Close': 104.0,
#   'Volume': 190.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-15': {'Open': 101.252,
#   'High': 105.05,
#   'Low': 101.252,
#   'Close': 104.4,
#   'Volume': 119.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-12': {'Open': 102.0,
#   'High': 106.35,
#   'Low': 102.0,
#   'Close': 103.7,
#   'Volume': 316.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-11': {'Open': 98.069,
#   'High': 100.2,
#   'Low': 98.069,
#   'Close': 100.2,
#   'Volume': 34.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-10': {'Open': 97.136,
#   'High': 99.84,
#   'Low': 97.136,
#   'Close': 99.84,
#   'Volume': 5.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-09': {'Open': 99.753,
#   'High': 100.2,
#   'Low': 99.753,
#   'Close': 100.0,
#   'Volume': 130.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-08': {'Open': 95.403,
#   'High': 98.93,
#   'Low': 95.403,
#   'Close': 98.93,
#   'Volume': 175.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-05': {'Open': 95.445,
#   'High': 97.9,
#   'Low': 95.445,
#   'Close': 97.9,
#   'Volume': 44.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-04': {'Open': 94.752,
#   'High': 98.474,
#   'Low': 94.752,
#   'Close': 98.474,
#   'Volume': 15.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-03': {'Open': 95.05,
#   'High': 96.5,
#   'Low': 95.05,
#   'Close': 96.5,
#   'Volume': 40.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-02': {'Open': 94.802,
#   'High': 97.96,
#   'Low': 94.802,
#   'Close': 96.02,
#   'Volume': 340.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-05-01': {'Open': 95.006,
#   'High': 95.006,
#   'Low': 95.006,
#   'Close': 95.006,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-28': {'Open': 95.006,
#   'High': 95.006,
#   'Low': 95.006,
#   'Close': 95.006,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-27': {'Open': 94.709,
#   'High': 97.49,
#   'Low': 94.709,
#   'Close': 97.49,
#   'Volume': 17.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-26': {'Open': 94.6,
#   'High': 97.46,
#   'Low': 94.5,
#   'Close': 97.46,
#   'Volume': 246.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-25': {'Open': 92.585,
#   'High': 94.313,
#   'Low': 92.585,
#   'Close': 94.313,
#   'Volume': 590.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-24': {'Open': 92.1,
#   'High': 92.1,
#   'Low': 92.1,
#   'Close': 92.1,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-21': {'Open': 92.1,
#   'High': 93.3,
#   'Low': 92.1,
#   'Close': 92.99,
#   'Volume': 155.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-20': {'Open': 91.0,
#   'High': 91.0,
#   'Low': 91.0,
#   'Close': 91.0,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-19': {'Open': 94.0,
#   'High': 94.0,
#   'Low': 94.0,
#   'Close': 94.0,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-18': {'Open': 94.0,
#   'High': 94.83,
#   'Low': 94.0,
#   'Close': 94.0,
#   'Volume': 257.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-17': {'Open': 93.16,
#   'High': 93.16,
#   'Low': 93.16,
#   'Close': 93.16,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-14': {'Open': 93.16,
#   'High': 93.16,
#   'Low': 93.16,
#   'Close': 93.16,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-13': {'Open': 91.869,
#   'High': 94.143,
#   'Low': 91.869,
#   'Close': 93.16,
#   'Volume': 200.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-12': {'Open': 95.0,
#   'High': 95.0,
#   'Low': 94.212,
#   'Close': 94.515,
#   'Volume': 90.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-11': {'Open': 95.84,
#   'High': 95.84,
#   'Low': 95.6,
#   'Close': 95.6,
#   'Volume': 134.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-10': {'Open': 95.84,
#   'High': 96.908,
#   'Low': 95.84,
#   'Close': 96.908,
#   'Volume': 10.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-07': {'Open': 95.75,
#   'High': 95.75,
#   'Low': 95.633,
#   'Close': 95.633,
#   'Volume': 30.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-06': {'Open': 96.3,
#   'High': 96.6,
#   'Low': 96.3,
#   'Close': 96.6,
#   'Volume': 38.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-05': {'Open': 95.0,
#   'High': 97.5,
#   'Low': 95.0,
#   'Close': 96.8,
#   'Volume': 65.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-04': {'Open': 98.8,
#   'High': 98.8,
#   'Low': 97.99,
#   'Close': 97.99,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-04-03': {'Open': 98.0,
#   'High': 98.0,
#   'Low': 98.0,
#   'Close': 98.0,
#   'Volume': 30.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-31': {'Open': 98.342,
#   'High': 100.75,
#   'Low': 98.342,
#   'Close': 100.31,
#   'Volume': 260.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-30': {'Open': 99.8,
#   'High': 100.75,
#   'Low': 99.8,
#   'Close': 100.75,
#   'Volume': 55.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-29': {'Open': 102.571,
#   'High': 102.571,
#   'Low': 101.332,
#   'Close': 101.332,
#   'Volume': 39.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-28': {'Open': 98.357,
#   'High': 98.357,
#   'Low': 98.357,
#   'Close': 98.357,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-27': {'Open': 98.585,
#   'High': 98.585,
#   'Low': 98.585,
#   'Close': 98.585,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-24': {'Open': 97.911,
#   'High': 97.911,
#   'Low': 97.911,
#   'Close': 97.911,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-23': {'Open': 99.525,
#   'High': 100.329,
#   'Low': 99.525,
#   'Close': 100.329,
#   'Volume': 100.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-22': {'Open': 102.5,
#   'High': 102.5,
#   'Low': 102.5,
#   'Close': 102.5,
#   'Volume': 70.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-21': {'Open': 102.5,
#   'High': 102.5,
#   'Low': 102.5,
#   'Close': 102.5,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-20': {'Open': 101.939,
#   'High': 101.939,
#   'Low': 101.939,
#   'Close': 101.939,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-17': {'Open': 101.835,
#   'High': 101.835,
#   'Low': 101.835,
#   'Close': 101.835,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-16': {'Open': 102.262,
#   'High': 105.35,
#   'Low': 102.262,
#   'Close': 104.5,
#   'Volume': 93.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-15': {'Open': 103.475,
#   'High': 103.475,
#   'Low': 103.475,
#   'Close': 103.475,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-14': {'Open': 103.828,
#   'High': 103.828,
#   'Low': 103.828,
#   'Close': 103.828,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-13': {'Open': 107.628,
#   'High': 107.628,
#   'Low': 106.7,
#   'Close': 106.7,
#   'Volume': 203.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-10': {'Open': 103.957,
#   'High': 106.037,
#   'Low': 103.874,
#   'Close': 103.874,
#   'Volume': 51.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-09': {'Open': 103.65,
#   'High': 103.65,
#   'Low': 103.65,
#   'Close': 103.65,
#   'Volume': 9.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-08': {'Open': 104.127,
#   'High': 105.1,
#   'Low': 104.127,
#   'Close': 105.1,
#   'Volume': 13.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-07': {'Open': 104.384,
#   'High': 107.3,
#   'Low': 104.384,
#   'Close': 107.3,
#   'Volume': 15.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-06': {'Open': 104.589,
#   'High': 106.95,
#   'Low': 104.589,
#   'Close': 106.95,
#   'Volume': 10.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-03': {'Open': 104.414,
#   'High': 104.414,
#   'Low': 104.414,
#   'Close': 104.414,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-02': {'Open': 107.0,
#   'High': 107.45,
#   'Low': 107.0,
#   'Close': 107.45,
#   'Volume': 71.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-03-01': {'Open': 104.143,
#   'High': 108.0,
#   'Low': 104.143,
#   'Close': 108.0,
#   'Volume': 11.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-28': {'Open': 104.658,
#   'High': 104.658,
#   'Low': 104.658,
#   'Close': 104.658,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-27': {'Open': 105.457,
#   'High': 105.457,
#   'Low': 105.457,
#   'Close': 105.457,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-24': {'Open': 109.0,
#   'High': 109.0,
#   'Low': 108.0,
#   'Close': 108.0,
#   'Volume': 330.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-23': {'Open': 105.383,
#   'High': 109.125,
#   'Low': 105.383,
#   'Close': 109.125,
#   'Volume': 151.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-22': {'Open': 105.484,
#   'High': 105.484,
#   'Low': 105.484,
#   'Close': 105.484,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-21': {'Open': 108.9,
#   'High': 108.9,
#   'Low': 107.699,
#   'Close': 107.699,
#   'Volume': 100.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-20': {'Open': 105.869,
#   'High': 108.301,
#   'Low': 105.869,
#   'Close': 107.2,
#   'Volume': 137.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-17': {'Open': 104.187,
#   'High': 107.5,
#   'Low': 104.187,
#   'Close': 107.5,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-16': {'Open': 103.006,
#   'High': 107.0,
#   'Low': 103.006,
#   'Close': 105.468,
#   'Volume': 200.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-15': {'Open': 102.779,
#   'High': 105.627,
#   'Low': 102.779,
#   'Close': 105.627,
#   'Volume': 150.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-14': {'Open': 102.792,
#   'High': 105.4,
#   'Low': 102.792,
#   'Close': 105.3,
#   'Volume': 178.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-13': {'Open': 104.5,
#   'High': 105.5,
#   'Low': 103.4,
#   'Close': 105.5,
#   'Volume': 152.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-10': {'Open': 102.5,
#   'High': 103.9,
#   'Low': 102.5,
#   'Close': 103.0,
#   'Volume': 95.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-09': {'Open': 102.5,
#   'High': 103.55,
#   'Low': 102.5,
#   'Close': 103.55,
#   'Volume': 50.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-08': {'Open': 101.375,
#   'High': 101.375,
#   'Low': 101.375,
#   'Close': 101.375,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-07': {'Open': 101.0,
#   'High': 104.935,
#   'Low': 101.0,
#   'Close': 104.1,
#   'Volume': 66.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-06': {'Open': 100.925,
#   'High': 104.1,
#   'Low': 100.925,
#   'Close': 103.5,
#   'Volume': 65.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-03': {'Open': 102.868,
#   'High': 106.974,
#   'Low': 102.1,
#   'Close': 103.0,
#   'Volume': 376.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-02-02': {'Open': 105.627,
#   'High': 105.627,
#   'Low': 104.3,
#   'Close': 104.95,
#   'Volume': 201.0,
#   'Adjustment Factor': 1.0,
#   'Adjustment Type': 3.0},
#  '2017-02-01': {'Open': 114.658,
#   'High': 114.658,
#   'Low': 103.3,
#   'Close': 107.45,
#   'Volume': 1162.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-31': {'Open': 118.38,
#   'High': 118.38,
#   'Low': 115.282,
#   'Close': 115.282,
#   'Volume': 150.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-30': {'Open': 118.992,
#   'High': 118.992,
#   'Low': 118.992,
#   'Close': 118.992,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-27': {'Open': 118.36,
#   'High': 123.409,
#   'Low': 118.36,
#   'Close': 123.409,
#   'Volume': 40.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-26': {'Open': 123.108,
#   'High': 123.108,
#   'Low': 123.108,
#   'Close': 123.108,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-25': {'Open': 119.95,
#   'High': 119.95,
#   'Low': 119.95,
#   'Close': 119.95,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-24': {'Open': 120.437,
#   'High': 122.0,
#   'Low': 120.437,
#   'Close': 122.0,
#   'Volume': 13.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-23': {'Open': 120.034,
#   'High': 120.034,
#   'Low': 120.034,
#   'Close': 120.034,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-20': {'Open': 120.554,
#   'High': 120.554,
#   'Low': 120.554,
#   'Close': 120.554,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-19': {'Open': 121.776,
#   'High': 121.776,
#   'Low': 121.776,
#   'Close': 121.776,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-18': {'Open': 122.296,
#   'High': 123.8,
#   'Low': 122.296,
#   'Close': 123.8,
#   'Volume': 16.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-17': {'Open': 126.0,
#   'High': 126.0,
#   'Low': 123.55,
#   'Close': 125.4,
#   'Volume': 119.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-16': {'Open': 121.533,
#   'High': 125.6,
#   'Low': 121.533,
#   'Close': 125.6,
#   'Volume': 24.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-13': {'Open': 116.483,
#   'High': 126.788,
#   'Low': 116.483,
#   'Close': 126.788,
#   'Volume': 106.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-12': {'Open': 114.038,
#   'High': 118.25,
#   'Low': 114.038,
#   'Close': 118.25,
#   'Volume': 150.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-11': {'Open': 114.048,
#   'High': 117.85,
#   'Low': 114.048,
#   'Close': 117.85,
#   'Volume': 40.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-10': {'Open': 113.095,
#   'High': 113.095,
#   'Low': 113.095,
#   'Close': 113.095,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-09': {'Open': 113.97,
#   'High': 113.97,
#   'Low': 113.97,
#   'Close': 113.97,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-06': {'Open': 113.849,
#   'High': 113.849,
#   'Low': 113.849,
#   'Close': 113.849,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-05': {'Open': 113.234,
#   'High': 113.234,
#   'Low': 113.234,
#   'Close': 113.234,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-04': {'Open': 113.0,
#   'High': 113.0,
#   'Low': 113.0,
#   'Close': 113.0,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-03': {'Open': 113.0,
#   'High': 113.0,
#   'Low': 113.0,
#   'Close': 113.0,
#   'Volume': 0.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None},
#  '2017-01-02': {'Open': 114.65,
#   'High': 114.65,
#   'Low': 114.36,
#   'Close': 114.36,
#   'Volume': 30.0,
#   'Adjustment Factor': None,
#   'Adjustment Type': None}}
